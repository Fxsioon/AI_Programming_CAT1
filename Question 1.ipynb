# %%
name = "Wesley Jr"
age = 19
is_AI_student = True

print(f" Hello, my name is {name}. I am {age} years old and AI student status is {is_AI_student}.")
# Out:
#  Hello, my name is Wesley Jr. I am 19 years old and AI student status is True.
